# %% [markdown]
# # Customer Segmentation Using Unsupervised Learning
#
# ## Objective
# Cluster customers based on spending habits and propose marketing strategies tailored to each segment.
#
# ## Dataset
# Mall Customers Dataset
# https://www.kaggle.com/datasets/vjchoudhary7/customer-segmentation-tutorial-in-python

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('/content/sample_data/Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
df.info()
df.describe()

sns.pairplot(df)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ## 4. Feature Selection

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 5. Finding Optimal Clusters (Elbow Method)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ## 6. Apply K-Means Clustering

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        4
# 1        2
# 2        4
# 3        2
# 4        4

# %% [markdown]
# ## 7. Visualize Clusters

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=df['Cluster'], cmap='viridis')
plt.title('Customer Segments')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %% [markdown]
# ## 8. PCA Visualization

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df['Cluster'], cmap='viridis')
plt.title('PCA Cluster Visualization')
plt.show()

# %%
cluster_summary = df.groupby('Cluster')[['Annual Income (k$)', 'Spending Score (1-100)']].mean()
print(cluster_summary)
# Out:
#          Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0                 55.296296               49.518519
# 1                 86.538462               82.128205
# 2                 25.727273               79.363636
# 3                 88.200000               17.114286
# 4                 26.304348               20.913043

# %% [markdown]
# ## 9. Marketing Strategies
#
# Cluster 0: Moderate income, moderate spending ,Target with mid-range products
#
# Cluster 1: High income, high spending  Target ,with premium/luxury products
#
# Cluster 2: Low income, high spending ,Offer discounts & loyalty programs
#
# Cluster 3: High income, low spending ,Encourage spending via exclusive offers
#
# Cluster 4: Low income, low spending ,Budget-friendly marketing
